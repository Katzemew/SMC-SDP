# %%
import pandas as pd

data = pd.read_csv("https://raw.githubusercontent.com/Insiya24/datasets/main/WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
data
# Out:
#       Age Attrition              Department  DistanceFromHome EducationField  \
# 0      41       Yes                   Sales                 1  Life Sciences
# 1      49        No  Research & Development                 8  Life Sciences
# 2      37       Yes  Research & Development                 2          Other
# 3      33        No  Research & Development                 3  Life Sciences
# 4      27        No  Research & Development                 2        Medical
# ...   ...       ...                     ...               ...            ...
# 1465   36        No  Research & Development                23        Medical
# 1466   39        No  Research & Development                 6        Medical
# 1467   27        No  Research & Development                 4  Life Sciences
# 1468   49        No                   Sales                 2        Medical
# 1469   34        No  Research & Development                 8        Medical
#
#       EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0               1.0             1.0                      2.0  Female
# 1               1.0             2.0                      3.0    Male
# 2               1.0             4.0                      4.0    Male
# 3               1.0             5.0                      4.0  Female
# 4               NaN             7.0                      1.0    Male
# ...             ...             ...                      ...     ...
# 1465            1.0          2061.0                      3.0    Male
# 1466            1.0          2062.0                      4.0    Male
# 1467            1.0          2064.0                      2.0    Male
# 1468            1.0          2065.0                      4.0    Male
# 1469            1.0          2068.0                      2.0    Male
#
#       HourlyRate  ...  MonthlyRate  OverTime  PercentSalaryHike  \
# 0           94.0  ...        19479       Yes               11.0
# 1           61.0  ...        24907        No               23.0
# 2           92.0  ...         2396       Yes               15.0
# 3           56.0  ...        23159       Yes                NaN
# 4           40.0  ...        16632        No               12.0
# ...          ...  ...          ...       ...                ...
# 1465        41.0  ...        12290        No               17.0
# 1466        42.0  ...        21457        No               15.0
# 1467        87.0  ...         5174       Yes               20.0
# 1468        63.0  ...        13243        No               14.0
# 1469        82.0  ...        10228        No               12.0
#
#      PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                    3                         1             80
# 1                    4                         4             80
# 2                    3                         2             80
# 3                    3                         3             80
# 4                    3                         4             80
# ...                ...                       ...            ...
# 1465                 3                         3             80
# 1466                 3                         1             80
# 1467                 4                         2             80
# 1468                 3                         4             80
# 1469                 3                         1             80
#
#      TotalWorkingYears  WorkLifeBalance  YearsAtCompany  \
# 0                    8                1               6
# 1                   10                3              10
# 2                    7                3               0
# 3                    8                3               8
# 4                    6                3               2
# ...                ...              ...             ...
# 1465                17                3               5
# 1466                 9                3               7
# 1467                 6                3               6
# 1468                17                2               9
# 1469                 6                4               4
#
#       YearsSinceLastPromotion
# 0                           0
# 1                           1
# 2                           0
# 3                           3
# 4                           2
# ...                       ...
# 1465                        0
# 1466                        1
# 1467                        0
# 1468                        0
# 1469                        1
#
# [1470 rows x 25 columns]

# %%
data.axes
# Out:
# [RangeIndex(start=0, stop=1470, step=1),
#  Index(['Age', 'Attrition', 'Department', 'DistanceFromHome', 'EducationField',
#         'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#         'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction',
#         'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'OverTime',
#         'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#         'StandardHours', 'TotalWorkingYears', 'WorkLifeBalance',
#         'YearsAtCompany', 'YearsSinceLastPromotion'],
#        dtype='object')]

# %%
data.shape
# Out:
# (1470, 25)

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'Department', 'DistanceFromHome', 'EducationField',
#        'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StandardHours', 'TotalWorkingYears', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsSinceLastPromotion'],
#       dtype='object')

# %%
data.size
# Out:
# 36750

# %%
data.values
# Out:
# array([[41, 'Yes', 'Sales', ..., 1, 6, 0],
#        [49, 'No', 'Research & Development', ..., 3, 10, 1],
#        [37, 'Yes', 'Research & Development', ..., 3, 0, 0],
#        ...,
#        [27, 'No', 'Research & Development', ..., 3, 6, 0],
#        [49, 'No', 'Sales', ..., 2, 9, 0],
#        [34, 'No', 'Research & Development', ..., 4, 4, 1]], dtype=object)

# %%
data.dtypes
# Out:
# Age                           int64
# Attrition                    object
# Department                   object
# DistanceFromHome              int64
# EducationField               object
# EmployeeCount               float64
# EmployeeNumber              float64
# EnvironmentSatisfaction     float64
# Gender                       object
# HourlyRate                  float64
# JobInvolvement              float64
# JobLevel                    float64
# JobSatisfaction             float64
# MaritalStatus                object
# MonthlyIncome                 int64
# MonthlyRate                   int64
# OverTime                     object
# PercentSalaryHike           float64
# PerformanceRating             int64
# RelationshipSatisfaction      int64
# StandardHours                 int64
# TotalWorkingYears             int64
# WorkLifeBalance               int64
# YearsAtCompany                int64
# YearsSinceLastPromotion       int64
# dtype: object

# %%
data.count()
# Out:
# Age                         1470
# Attrition                   1470
# Department                  1468
# DistanceFromHome            1470
# EducationField              1451
# EmployeeCount               1468
# EmployeeNumber              1468
# EnvironmentSatisfaction     1469
# Gender                      1458
# HourlyRate                  1467
# JobInvolvement              1449
# JobLevel                    1456
# JobSatisfaction             1459
# MaritalStatus               1470
# MonthlyIncome               1470
# MonthlyRate                 1470
# OverTime                    1470
# PercentSalaryHike           1464
# PerformanceRating           1470
# RelationshipSatisfaction    1470
# StandardHours               1470
# TotalWorkingYears           1470
# WorkLifeBalance             1470
# YearsAtCompany              1470
# YearsSinceLastPromotion     1470
# dtype: int64

# %%
data.ndim
# Out:
# 2

# %%
data.head(15)
# Out:
#     Age Attrition              Department  DistanceFromHome EducationField  \
# 0    41       Yes                   Sales                 1  Life Sciences
# 1    49        No  Research & Development                 8  Life Sciences
# 2    37       Yes  Research & Development                 2          Other
# 3    33        No  Research & Development                 3  Life Sciences
# 4    27        No  Research & Development                 2        Medical
# 5    32        No  Research & Development                 2  Life Sciences
# 6    59        No  Research & Development                 3        Medical
# 7    30        No  Research & Development                24  Life Sciences
# 8    38        No  Research & Development                23  Life Sciences
# 9    36        No  Research & Development                27        Medical
# 10   35        No  Research & Development                16        Medical
# 11   29        No  Research & Development                15  Life Sciences
# 12   31        No  Research & Development                26  Life Sciences
# 13   34        No  Research & Development                19        Medical
# 14   28       Yes  Research & Development                24  Life Sciences
#
#     EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0             1.0             1.0                      2.0  Female
# 1             1.0             2.0                      3.0    Male
# 2             1.0             4.0                      4.0    Male
# 3             1.0             5.0                      4.0  Female
# 4             NaN             7.0                      1.0    Male
# 5             1.0             8.0                      4.0    Male
# 6             1.0            10.0                      3.0  Female
# 7             1.0            11.0                      4.0    Male
# 8             1.0            12.0                      4.0    Male
# 9             1.0            13.0                      3.0    Male
# 10            1.0            14.0                      1.0    Male
# 11            1.0            15.0                      4.0  Female
# 12            1.0            16.0                      NaN    Male
# 13            1.0            18.0                      2.0    Male
# 14            1.0            19.0                      3.0    Male
#
#     HourlyRate  ...  MonthlyRate  OverTime  PercentSalaryHike  \
# 0         94.0  ...        19479       Yes               11.0
# 1         61.0  ...        24907        No               23.0
# 2         92.0  ...         2396       Yes               15.0
# 3         56.0  ...        23159       Yes                NaN
# 4         40.0  ...        16632        No               12.0
# 5         79.0  ...        11864        No               13.0
# 6         81.0  ...         9964       Yes               20.0
# 7         67.0  ...        13335        No               22.0
# 8         44.0  ...         8787        No               21.0
# 9         94.0  ...        16577        No               13.0
# 10        84.0  ...        16479        No               13.0
# 11        49.0  ...        12682       Yes               12.0
# 12        31.0  ...        15170        No               17.0
# 13        93.0  ...         8758        No               11.0
# 14        50.0  ...        12947       Yes               14.0
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         1             80
# 1                  4                         4             80
# 2                  3                         2             80
# 3                  3                         3             80
# 4                  3                         4             80
# 5                  3                         3             80
# 6                  4                         1             80
# 7                  4                         2             80
# 8                  4                         2             80
# 9                  3                         2             80
# 10                 3                         3             80
# 11                 3                         4             80
# 12                 3                         4             80
# 13                 3                         3             80
# 14                 3                         2             80
#
#    TotalWorkingYears  WorkLifeBalance  YearsAtCompany  YearsSinceLastPromotion
# 0                  8                1               6                        0
# 1                 10                3              10                        1
# 2                  7                3               0                        0
# 3                  8                3               8                        3
# 4                  6                3               2                        2
# 5                  8                2               7                        3
# 6                 12                2               1                        0
# 7                  1                3               1                        0
# 8                 10                3               9                        1
# 9                 17                2               7                        7
# 10                 6                3               5                        0
# 11                10                3               9                        0
# 12                 5                2               5                        4
# 13                 3                3               2                        1
# 14                 6                3               4                        0
#
# [15 rows x 25 columns]

# %%
data.tail(15)
# Out:
#       Age Attrition              Department  DistanceFromHome EducationField  \
# 1455   40        No  Research & Development                 2  Life Sciences
# 1456   35        No  Research & Development                18  Life Sciences
# 1457   40        No  Research & Development                 2        Medical
# 1458   35        No  Research & Development                 1  Life Sciences
# 1459   29        No  Research & Development                13          Other
# 1460   29        No  Research & Development                28        Medical
# 1461   50       Yes                   Sales                28      Marketing
# 1462   39        No                   Sales                24      Marketing
# 1463   31        No  Research & Development                 5        Medical
# 1464   26        No                   Sales                 5          Other
# 1465   36        No  Research & Development                23        Medical
# 1466   39        No  Research & Development                 6        Medical
# 1467   27        No  Research & Development                 4  Life Sciences
# 1468   49        No                   Sales                 2        Medical
# 1469   34        No  Research & Development                 8        Medical
#
#       EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 1455            1.0          2048.0                      3.0    Male
# 1456            1.0          2049.0                      3.0    Male
# 1457            1.0          2051.0                      3.0  Female
# 1458            1.0          2052.0                      3.0  Female
# 1459            1.0          2053.0                      4.0    Male
# 1460            1.0          2054.0                      4.0  Female
# 1461            1.0          2055.0                      4.0    Male
# 1462            1.0          2056.0                      2.0  Female
# 1463            1.0          2057.0                      2.0    Male
# 1464            1.0          2060.0                      4.0  Female
# 1465            1.0          2061.0                      3.0    Male
# 1466            1.0          2062.0                      4.0    Male
# 1467            1.0          2064.0                      2.0    Male
# 1468            1.0          2065.0                      4.0    Male
# 1469            1.0          2068.0                      2.0    Male
#
#       HourlyRate  ...  MonthlyRate  OverTime  PercentSalaryHike  \
# 1455        52.0  ...         2725        No               14.0
# 1456        80.0  ...        24594       Yes               14.0
# 1457        98.0  ...        12549        No               14.0
# 1458        62.0  ...         8952        No               12.0
# 1459        46.0  ...        23679       Yes               13.0
# 1460        73.0  ...         8489        No               14.0
# 1461        39.0  ...        16586       Yes               13.0
# 1462        60.0  ...         8828        No               11.0
# 1463        74.0  ...         3787        No               19.0
# 1464        30.0  ...        21378        No               18.0
# 1465        41.0  ...        12290        No               17.0
# 1466        42.0  ...        21457        No               15.0
# 1467        87.0  ...         5174       Yes               20.0
# 1468        63.0  ...        13243        No               14.0
# 1469        82.0  ...        10228        No               12.0
#
#      PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 1455                 3                         4             80
# 1456                 3                         4             80
# 1457                 3                         2             80
# 1458                 3                         4             80
# 1459                 3                         1             80
# 1460                 3                         2             80
# 1461                 3                         2             80
# 1462                 3                         1             80
# 1463                 3                         2             80
# 1464                 3                         4             80
# 1465                 3                         3             80
# 1466                 3                         1             80
# 1467                 4                         2             80
# 1468                 3                         4             80
# 1469                 3                         1             80
#
#      TotalWorkingYears  WorkLifeBalance  YearsAtCompany  \
# 1455                 8                3               2
# 1456                10                4              10
# 1457                20                3               5
# 1458                 4                3               4
# 1459                10                3               4
# 1460                 5                1               5
# 1461                20                3               3
# 1462                21                2              20
# 1463                10                3               9
# 1464                 5                3               4
# 1465                17                3               5
# 1466                 9                3               7
# 1467                 6                3               6
# 1468                17                2               9
# 1469                 6                4               4
#
#       YearsSinceLastPromotion
# 1455                        2
# 1456                        0
# 1457                        0
# 1458                        1
# 1459                        0
# 1460                        0
# 1461                        2
# 1462                        9
# 1463                        1
# 1464                        0
# 1465                        0
# 1466                        1
# 1467                        0
# 1468                        0
# 1469                        1
#
# [15 rows x 25 columns]

# %%
data_EF = data.groupby(["Age"])[["YearsAtCompany"]]

# %%
data_EF.mean()
# Out:
#      YearsAtCompany
# Age
# 18         0.000000
# 19         0.777778
# 20         1.545455
# 21         1.846154
# 22         2.062500
# 23         2.642857
# 24         3.346154
# 25         3.846154
# 26         4.692308
# 27         5.020833
# 28         4.375000
# 29         5.602941
# 30         6.516667
# 31         5.681159
# 32         6.131148
# 33         6.586207
# 34         7.064935
# 35         6.794872
# 36         7.405797
# 37         6.380000
# 38         6.534483
# 39         9.761905
# 40         8.438596
# 41         9.700000
# 42         8.326087
# 43         8.281250
# 44         8.272727
# 45         9.365854
# 46         8.939394
# 47        10.041667
# 48         6.421053
# 49         8.416667
# 50        10.800000
# 51        10.052632
# 52        12.444444
# 53         9.736842
# 54         7.333333
# 55        11.909091
# 56         6.857143
# 57         5.250000
# 58        11.571429
# 59         5.800000
# 60        12.200000

# %%
data_EF.median()
# Out:
#      YearsAtCompany
# Age
# 18              0.0
# 19              1.0
# 20              2.0
# 21              2.0
# 22              2.0
# 23              3.0
# 24              4.0
# 25              3.5
# 26              5.0
# 27              5.0
# 28              4.0
# 29              5.0
# 30              6.5
# 31              5.0
# 32              6.0
# 33              6.0
# 34              6.0
# 35              6.0
# 36              7.0
# 37              5.5
# 38              5.5
# 39              7.5
# 40              6.0
# 41              7.5
# 42              5.0
# 43              6.5
# 44              5.0
# 45              8.0
# 46              8.0
# 47              7.0
# 48              3.0
# 49              7.0
# 50              5.5
# 51              7.0
# 52              8.0
# 53              7.0
# 54              5.5
# 55              8.5
# 56              5.5
# 57              4.0
# 58              5.5
# 59              4.5
# 60             11.0

# %%
data[data["HourlyRate"]>99]
# Out:
#       Age Attrition              Department  DistanceFromHome  \
# 104    37        No  Research & Development                 2
# 128    22        No  Research & Development                 2
# 171    19       Yes                   Sales                 1
# 241    32        No                   Sales                26
# 260    32        No  Research & Development                 7
# 274    21        No  Research & Development                 3
# 303    31        No                   Sales                 7
# 367    50        No  Research & Development                10
# 504    45       Yes                   Sales                26
# 606    34        No  Research & Development                16
# 673    33        No  Research & Development                 1
# 706    40       Yes                   Sales                24
# 835    35        No         Human Resources                 8
# 1004   26        No  Research & Development                 7
# 1033   31       Yes  Research & Development                 1
# 1077   29       Yes  Research & Development                 1
# 1289   38        No         Human Resources                 2
# 1451   38        No                   Sales                10
# 1453   36        No                   Sales                11
#
#         EducationField  EmployeeCount  EmployeeNumber  \
# 104      Life Sciences            1.0           139.0
# 128   Technical Degree            1.0           169.0
# 171   Technical Degree            1.0           235.0
# 241          Marketing            1.0           333.0
# 260      Life Sciences            1.0           359.0
# 274            Medical            1.0           379.0
# 303   Technical Degree            1.0           416.0
# 367   Technical Degree            1.0           491.0
# 504      Life Sciences            1.0           684.0
# 606      Life Sciences            1.0           838.0
# 673              Other            1.0           939.0
# 706      Life Sciences            1.0           986.0
# 835   Technical Degree            1.0          1164.0
# 1004             Other            1.0          1417.0
# 1033     Life Sciences            1.0          1459.0
# 1077  Technical Degree            1.0          1522.0
# 1289   Human Resources            1.0          1805.0
# 1451     Life Sciences            1.0          2041.0
# 1453         Marketing            1.0          2045.0
#
#       EnvironmentSatisfaction  Gender  HourlyRate  ...  MonthlyRate  OverTime  \
# 104                       3.0    Male       100.0  ...        15850        No
# 128                       3.0    Male       100.0  ...        19299        No
# 171                       3.0  Female       100.0  ...        20989        No
# 241                       3.0    Male       100.0  ...        12069        No
# 260                       2.0    Male       100.0  ...        26062        No
# 274                       4.0    Male       100.0  ...        10531        No
# 303                       2.0    Male       100.0  ...        12241        No
# 367                       4.0    Male       100.0  ...         2755        No
# 504                       1.0  Female       100.0  ...         5630        No
# 606                       3.0  Female       100.0  ...         8306        No
# 673                       3.0    Male       100.0  ...         3339       Yes
# 706                       2.0  Female       100.0  ...        17071       Yes
# 835                       3.0    Male       100.0  ...         7108        No
# 1004                      3.0    Male       100.0  ...        23577        No
# 1033                      3.0  Female       100.0  ...         8931        No
# 1077                      1.0    Male       100.0  ...         7568        No
# 1289                      1.0    Male       100.0  ...         7129        No
# 1451                      1.0  Female       100.0  ...         5982        No
# 1453                      2.0  Female       100.0  ...        14369        No
#
#       PercentSalaryHike PerformanceRating  RelationshipSatisfaction  \
# 104                14.0                 3                         4
# 128                14.0                 3                         3
# 171                21.0                 4                         1
# 241                18.0                 3                         1
# 260                20.0                 4                         3
# 274                17.0                 3                         1
# 303                11.0                 3                         2
# 367                15.0                 3                         4
# 504                14.0                 3                         4
# 606                16.0                 3                         3
# 673                11.0                 3                         2
# 706                16.0                 3                         4
# 835                17.0                 3                         2
# 1004               12.0                 3                         4
# 1033               11.0                 3                         1
# 1077               13.0                 3                         3
# 1289               13.0                 3                         4
# 1451               11.0                 3                         3
# 1453               13.0                 3                         1
#
#       StandardHours TotalWorkingYears  WorkLifeBalance  YearsAtCompany  \
# 104              80                17                4               1
# 128              80                 3                3               2
# 171              80                 1                4               0
# 241              80                 4                3               3
# 260              80                 5                1               5
# 274              80                 3                4               3
# 303              80                10                2               8
# 367              80                20                3               4
# 504              80                 5                3               1
# 606              80                 6                3               5
# 673              80                 6                3               3
# 706              80                22                2               1
# 835              80                 6                1               5
# 1004             80                 8                3               7
# 1033             80                10                3              10
# 1077             80                11                1               9
# 1289             80                13                3              11
# 1451             80                10                3              10
# 1453             80                 8                2               6
#
#       YearsSinceLastPromotion
# 104                         0
# 128                         2
# 171                         0
# 241                         2
# 260                         0
# 274                         1
# 303                         7
# 367                         1
# 504                         0
# 606                         1
# 673                         0
# 706                         0
# 835                         1
# 1004                        0
# 1033                        4
# 1077                        0
# 1289                        3
# 1451                        1
# 1453                        0
#
# [19 rows x 25 columns]

# %%
data.isnull()
# Out:
#         Age  Attrition  Department  DistanceFromHome  EducationField  \
# 0     False      False       False             False           False
# 1     False      False       False             False           False
# 2     False      False       False             False           False
# 3     False      False       False             False           False
# 4     False      False       False             False           False
# ...     ...        ...         ...               ...             ...
# 1465  False      False       False             False           False
# 1466  False      False       False             False           False
# 1467  False      False       False             False           False
# 1468  False      False       False             False           False
# 1469  False      False       False             False           False
#
#       EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0             False           False                    False   False
# 1             False           False                    False   False
# 2             False           False                    False   False
# 3             False           False                    False   False
# 4              True           False                    False   False
# ...             ...             ...                      ...     ...
# 1465          False           False                    False   False
# 1466          False           False                    False   False
# 1467          False           False                    False   False
# 1468          False           False                    False   False
# 1469          False           False                    False   False
#
#       HourlyRate  ...  MonthlyRate  OverTime  PercentSalaryHike  \
# 0          False  ...        False     False              False
# 1          False  ...        False     False              False
# 2          False  ...        False     False              False
# 3          False  ...        False     False               True
# 4          False  ...        False     False              False
# ...          ...  ...          ...       ...                ...
# 1465       False  ...        False     False              False
# 1466       False  ...        False     False              False
# 1467       False  ...        False     False              False
# 1468       False  ...        False     False              False
# 1469       False  ...        False     False              False
#
#       PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                 False                     False          False
# 1                 False                     False          False
# 2                 False                     False          False
# 3                 False                     False          False
# 4                 False                     False          False
# ...                 ...                       ...            ...
# 1465              False                     False          False
# 1466              False                     False          False
# 1467              False                     False          False
# 1468              False                     False          False
# 1469              False                     False          False
#
#       TotalWorkingYears  WorkLifeBalance  YearsAtCompany  \
# 0                 False            False           False
# 1                 False            False           False
# 2                 False            False           False
# 3                 False            False           False
# 4                 False            False           False
# ...                 ...              ...             ...
# 1465              False            False           False
# 1466              False            False           False
# 1467              False            False           False
# 1468              False            False           False
# 1469              False            False           False
#
#       YearsSinceLastPromotion
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 1465                    False
# 1466                    False
# 1467                    False
# 1468                    False
# 1469                    False
#
# [1470 rows x 25 columns]

# %%
data['EmployeeNumber'].mean()
# Out:
# 1026.0517711171663

# %%
data['EmployeeNumber'].fillna(1026.05177,inplace=True)

# %%
data['EmployeeCount'].mean()
# Out:
# 1.0

# %%
data['EmployeeCount'].fillna(1.0,inplace=True)

# %%
data['EnvironmentSatisfaction'].mean()
# Out:
# 2.7229407760381212

# %%
data['EnvironmentSatisfaction'].fillna(2.7229407760381212,inplace=True)

# %%
data['HourlyRate'].mean()
# Out:
# 65.88207225630539

# %%
data['HourlyRate'].fillna(65.88207225630539,inplace=True)

# %%
data['JobInvolvement'].mean()
# Out:
# 2.732919254658385

# %%
data['JobInvolvement'].fillna(2.732919254658385,inplace=True)

# %%
data['JobLevel'].mean()
# Out:
# 2.0611263736263736

# %%
data['JobLevel'].fillna(2.0611263736263736,inplace=True)

# %%
data['JobSatisfaction'].mean()
# Out:
# 2.726525017135024

# %%
data['JobSatisfaction'].fillna(2.726525017135024,inplace=True)

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()

# %%
data["Gender"]=le.fit_transform(data["Gender"])

# %%
data["Gender"].value_counts()
# Out:
# Gender
# 1    874
# 0    584
# 2     12
# Name: count, dtype: int64

# %%
data["Department"]=le.fit_transform(data["Department"])

# %%
data['Department'].value_counts()
# Out:
# Department
# 1    961
# 2    444
# 0     63
# 3      2
# Name: count, dtype: int64

# %%
data["PercentSalaryHike"]=le.fit_transform(data["PercentSalaryHike"])

# %%
data['PercentSalaryHike'].value_counts()
# Out:
# PercentSalaryHike
# 2     209
# 0     207
# 3     201
# 1     197
# 4      99
# 7      89
# 6      82
# 5      78
# 8      76
# 11     56
# 9      55
# 10     48
# 12     28
# 13     21
# 14     18
# 15      6
# Name: count, dtype: int64

# %%
data["EducationField"]=le.fit_transform(data["EducationField"])

# %%
data['EducationField'].value_counts()
# Out:
# EducationField
# 1    600
# 3    454
# 2    159
# 5    131
# 4     81
# 0     26
# 6     19
# Name: count, dtype: int64

# %%
data.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# Department                  0
# DistanceFromHome            0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# TotalWorkingYears           0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# dtype: int64

# %%
data
# Out:
#       Age  Attrition  Department  DistanceFromHome  EducationField  \
# 0      41          1           2                 1               1
# 1      49          0           1                 8               1
# 2      37          1           1                 2               4
# 3      33          0           1                 3               1
# 4      27          0           1                 2               3
# ...   ...        ...         ...               ...             ...
# 1465   36          0           1                23               3
# 1466   39          0           1                 6               3
# 1467   27          0           1                 4               1
# 1468   49          0           2                 2               3
# 1469   34          0           1                 8               3
#
#       EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0               1.0             1.0                      2.0       0
# 1               1.0             2.0                      3.0       1
# 2               1.0             4.0                      4.0       1
# 3               1.0             5.0                      4.0       0
# 4               1.0             7.0                      1.0       1
# ...             ...             ...                      ...     ...
# 1465            1.0          2061.0                      3.0       1
# 1466            1.0          2062.0                      4.0       1
# 1467            1.0          2064.0                      2.0       1
# 1468            1.0          2065.0                      4.0       1
# 1469            1.0          2068.0                      2.0       1
#
#       HourlyRate  ...  MonthlyRate  OverTime  PercentSalaryHike  \
# 0           94.0  ...        19479         1                  0
# 1           61.0  ...        24907         0                 12
# 2           92.0  ...         2396         1                  4
# 3           56.0  ...        23159         1                 15
# 4           40.0  ...        16632         0                  1
# ...          ...  ...          ...       ...                ...
# 1465        41.0  ...        12290         0                  6
# 1466        42.0  ...        21457         0                  4
# 1467        87.0  ...         5174         1                  9
# 1468        63.0  ...        13243         0                  3
# 1469        82.0  ...        10228         0                  1
#
#      PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                    3                         1             80
# 1                    4                         4             80
# 2                    3                         2             80
# 3                    3                         3             80
# 4                    3                         4             80
# ...                ...                       ...            ...
# 1465                 3                         3             80
# 1466                 3                         1             80
# 1467                 4                         2             80
# 1468                 3                         4             80
# 1469                 3                         1             80
#
#       TotalWorkingYears  WorkLifeBalance  YearsAtCompany  \
# 0                     8                1               6
# 1                    10                3              10
# 2                     7                3               0
# 3                     8                3               8
# 4                     6                3               2
# ...                 ...              ...             ...
# 1465                 17                3               5
# 1466                  9                3               7
# 1467                  6                3               6
# 1468                 17                2               9
# 1469                  6                4               4
#
#       YearsSinceLastPromotion
# 0                           0
# 1                           1
# 2                           0
# 3                           3
# 4                           2
# ...                       ...
# 1465                        0
# 1466                        1
# 1467                        0
# 1468                        0
# 1469                        1
#
# [1470 rows x 25 columns]

# %%
data["Attrition"]=le.fit_transform(data["Attrition"])

# %%
data['Attrition'].value_counts()
# Out:
# Attrition
# 0    1233
# 1     237
# Name: count, dtype: int64

# %%
data["OverTime"]=le.fit_transform(data["OverTime"])

# %%
data['OverTime'].value_counts()
# Out:
# OverTime
# 0    1054
# 1     416
# Name: count, dtype: int64

# %%
data.dtypes
# Out:
# Age                           int64
# Attrition                     int64
# Department                    int64
# DistanceFromHome              int64
# EducationField                int64
# EmployeeCount               float64
# EmployeeNumber              float64
# EnvironmentSatisfaction     float64
# Gender                        int64
# HourlyRate                  float64
# JobInvolvement              float64
# JobLevel                    float64
# JobSatisfaction             float64
# MaritalStatus                object
# MonthlyIncome                 int64
# MonthlyRate                   int64
# OverTime                      int64
# PercentSalaryHike             int64
# PerformanceRating             int64
# RelationshipSatisfaction      int64
# StandardHours                 int64
# TotalWorkingYears             int64
# WorkLifeBalance               int64
# YearsAtCompany                int64
# YearsSinceLastPromotion       int64
# dtype: object

# %%
data["MaritalStatus"]=le.fit_transform(data["MaritalStatus"])

# %%
data['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# 1    673
# 2    470
# 0    327
# Name: count, dtype: int64

# %%
import seaborn
import matplotlib.pyplot as pt
pt.figure(figsize=(20,20))
correlation = data.corr()
heatmap=seaborn.heatmap(correlation,annot=True)

pt.show()
